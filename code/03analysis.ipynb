# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %%
df = pd.read_csv("/Users/marcojavieralbabetances/Downloads/movie_project/data/raw/IMDB-Movie-Data.csv")

# %%
new_df = df.dropna()
new_df
# Out:
#      Unnamed: 0  Rank                     Title                     Genre  \
# 0             0     1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1             1     2                Prometheus  Adventure,Mystery,Sci-Fi
# 2             2     3                     Split           Horror,Thriller
# 3             3     4                      Sing   Animation,Comedy,Family
# 4             4     5             Suicide Squad  Action,Adventure,Fantasy
# ..          ...   ...                       ...                       ...
# 833         993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834         994   995                 Project X                    Comedy
# 835         996   997           Hostel: Part II                    Horror
# 836         997   998    Step Up 2: The Streets       Drama,Music,Romance
# 837         999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                  Director                                             Actors  \
# ...

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Revenue (Millions)"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Metascore"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Rating"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
#For the purpose of this dataset I focused on looking at runtime effect on other varaibles.
#In the film industry we have been seeing increase in runtime for movies so I was curios in seeing 
#how that affects revenue generated, metascore and rating of movies
#Based on the scatterplots provides above there isn't sufficent data of the making of movies to make a predictable conclsuion based on 
# y variables in relations to Runtime.

#What we do see is that movies who run between 100 minutes to 140 is the sweet spot where movies will 
# generate an average with other ovies of the same length and would typically reciebve good rating in votes and metascore betwween 100-140 minutes.
