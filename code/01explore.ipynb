# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %%
#creating dataframe 

df = pd.read_csv("/Users/marcojavieralbabetances/Downloads/movie_project/data/raw/IMDB-Movie-Data.csv")

# %%
#looking at dataset

df.head()
# Out:
#    Unnamed: 0  Rank                    Title                     Genre  \
# 0           0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1           1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2           2     3                    Split           Horror,Thriller
# 3           3     4                     Sing   Animation,Comedy,Family
# 4           4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                Director                                             Actors  \
# 0            James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    Year  Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# ...

# %%
#seeing stastics for numeroc columns

df.describe()
# Out:
#        Unnamed: 0         Rank        Year  Runtime (Minutes)      Rating  \
# count  838.000000   838.000000   838.00000         838.000000  838.000000
# mean   484.247017   485.247017  2012.50716         114.638425    6.814320
# std    286.572065   286.572065     3.17236          18.470922    0.877754
# min      0.000000     1.000000  2006.00000          66.000000    1.900000
# 25%    237.250000   238.250000  2010.00000         101.000000    6.300000
# 50%    474.500000   475.500000  2013.00000         112.000000    6.900000
# 75%    728.750000   729.750000  2015.00000         124.000000    7.500000
# max    999.000000  1000.000000  2016.00000         187.000000    9.000000
#
#               Votes  Revenue (Millions)   Metascore
# count  8.380000e+02          838.000000  838.000000
# mean   1.932303e+05           84.564558   59.575179
# std    1.930990e+05          104.520227   16.952416
# min    1.780000e+02            0.000000   11.000000
# ...

# %%
# Univariate Analysis 

df["Rating"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Revenue (Millions)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Metascore"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Runtime (Minutes)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Year"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Making a new dataframe for Revenue & Metascore

revenue_count = df.value_counts("Revenue (Millions)")

metascore_count = df.value_counts("Metascore")

votes_count = df.value_counts("Votes")

rating_count = df.value_counts("Rating")

# %%
rating_count
# Out:
# Rating
# 7.0    43
# 6.7    42
# 7.1    40
# 7.8    38
# 7.2    38
# 6.6    37
# 7.3    37
# 6.3    36
# 6.5    35
# 6.8    33
# 6.2    33
# 7.5    33
# 6.4    30
# 7.4    29
# 7.6    26
# 7.7    25
# 8.1    24
# 6.9    23
# 6.1    22
# 5.8    21
# 7.9    20
# 6.0    20
# 8.0    19
# 5.7    16
# 5.9    15
# 5.6    13
# 5.5    11
# 5.4    10
# 8.2     9
# 5.3     8
# 8.5     6
# 4.9     6
# 5.2     6
# 8.3     5
# 5.1     5
# 4.7     3
# 4.3     3
# 8.6     3
# 4.6     2
# 3.9     2
# 8.4     2
# 8.8     1
# 1.9     1
# 2.7     1
# 5.0     1
# 4.8     1
# 4.4     1
# 4.1     1
# 4.0     1
# 9.0     1
# Name: count, dtype: int64

# %%
votes_count
# Out:
# Votes
# 97141      2
# 178        1
# 217464     1
# 209326     1
# 209700     1
#           ..
# 84158      1
# 84765      1
# 84927      1
# 86271      1
# 1791916    1
# Name: count, Length: 837, dtype: int64

# %%
revenue_count
# Out:
# Revenue (Millions)
# 0.03      5
# 0.02      4
# 0.04      4
# 0.05      4
# 0.32      4
#          ..
# 31.86     1
# 31.99     1
# 32.28     1
# 32.39     1
# 936.63    1
# Name: count, Length: 789, dtype: int64

# %%
metascore_count
# Out:
# Metascore
# 66.0     24
# 68.0     23
# 72.0     22
# 57.0     22
# 64.0     21
#          ..
# 89.0      1
# 15.0      1
# 25.0      1
# 19.0      1
# 100.0     1
# Name: count, Length: 82, dtype: int64

# %%
votes_count.plot.bar()
# Out:
# <Axes: xlabel='Votes'>

# %%
plt.figure(figsize=(10,10))
rating_count.plot.barh()
# Out:
# <Axes: ylabel='Rating'>

# %%
plt.figure(figsize=(10,20))
revenue_count.plot.barh()
# Out:
# <Axes: ylabel='Revenue (Millions)'>

# %%
plt.figure(figsize=(10,10))
metascore_count.plot.barh()
# Out:
# <Axes: ylabel='Metascore'>

# %%
#Bivariate Analysis

# %%
sns.boxplot(data=df, x="Title", y="Revenue (Millions)")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.boxplot(data=df, x="Metascore", y="Revenue (Millions)")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10,20))
sns.boxplot(data=df, x="Votes", y="Metascore")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(30, 15))
sns.boxplot(data=df, x="Runtime (Minutes)", y="Revenue (Millions)")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(30, 10))
sns.boxplot(data=df, x="Runtime (Minutes)", y="Metascore")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x="Runtime (Minutes)", y="Votes")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
#Droping missing values

new_df = df.dropna()
new_df
# Out:
#      Unnamed: 0  Rank                     Title                     Genre  \
# 0             0     1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1             1     2                Prometheus  Adventure,Mystery,Sci-Fi
# 2             2     3                     Split           Horror,Thriller
# 3             3     4                      Sing   Animation,Comedy,Family
# 4             4     5             Suicide Squad  Action,Adventure,Fantasy
# ..          ...   ...                       ...                       ...
# 833         993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834         994   995                 Project X                    Comedy
# 835         996   997           Hostel: Part II                    Horror
# 836         997   998    Step Up 2: The Streets       Drama,Music,Romance
# 837         999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                  Director                                             Actors  \
# ...

# %%
sns.scatterplot(x=new_df["Rating"], y=new_df["Revenue (Millions)"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Rating"], y=new_df["Metascore"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Rating"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Rating"], y=new_df["Votes"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x=new_df["Title"], y=new_df["Revenue (Millions)"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Revenue (Millions)"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x=new_df["Runtime (Minutes)"], y=new_df["Metascore"])
sns.set_style("whitegrid")
plt.show()
# Out:
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/marcojavieralbabetances/Downloads/DS/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Bi
