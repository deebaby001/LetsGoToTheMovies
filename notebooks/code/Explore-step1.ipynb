# %% [markdown]
# ## Introduction
# I will be performing the Exploratory Data Analysis (EDA) utilizing the IMDB Movie dataset for the Years 2006 through 2016. IMDB is the premiere source of a plethora of theatrical, screen, video and stage recorded data.

# %% [markdown]
# ## Exploratory Data Analysis
# I will begin with exploring the data and then providing a brief analysis. In this process, I am gathering the dataset, cleaning the dataset and the providing some visualization of the data using various libraries as (but not limited to): Axes3D, StandardScaler, Matplotlib,Numpy, Pandas and various other applications and tools to Import Coding Libraries and Define Functions for Data Plotting.

# %%
#Load Environment and other coding packages
import pandas as pd 
from sklearn.preprocessing import StandardScaler
import matplotlib as plt # plotting
import numpy as np # linear algebra

# %% [markdown]
# There is 1 (.csv) file in the current version of the dataset: <IMDB-Movie-Data.csv>

# %%
#Read the Dataset csv file

df = pd.read_csv("C:/Users/deema/Desktop/EOP-01/LetsGoToTheMovies/Notebooks/data/raw/IMDB-Movie-Data.csv")

# %% [markdown]
# #Start Cleaning the Data
# #OK Here we go!

# %%
print(df)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# #Clean the dataframe

# %%
#Drop blanks and NA's from the dataframe
df = df.dropna()

# %% [markdown]
# #Data Visualizations

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
# Create a scatter plot matrix

df.plot.scatter(x='Rank', y='Rating')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()

# Add an Axes object to the figure
ax = plt.axes(projection='3d')

# Generate random data
xdata = np.random.standard_normal(100)
ydata = np.random.standard_normal(100)
zdata = np.random.standard_normal(100)

# Create a 3D scatter plot
ax.scatter3D(xdata, ydata, zdata)

# Display the plot
plt.show()

# %%
#Scatter Plot of "Rating" and "Revenue (Millions)"

# Create a scatter plot matrix
df.plot.scatter(x='Rating', y='Revenue (Millions)')
plt.show()

# %%
#Scatter Plot of "Metascore" and "Rating"
df.plot.scatter(x='Metascore', y='Rating')
plt.show()

# %%
#kde-Plot
import seaborn as sns
geyser = sns.load_dataset("geyser")
sns.kdeplot(data=geyser, x="waiting", y="duration")
# Out:
# <Axes: xlabel='waiting', ylabel='duration'>

# %%
#Create a Histplot
#Reviewing the Rank of the movies
import seaborn as sns
sns.histplot(data=df, x="Rank", bins=30, kde=True)
plt.show()

# %%
#Create a Histplot
#Reviewing the Metascore of the movies
import seaborn as sns

sns.histplot(data=df, x="Metascore", bins=30, kde=True)
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis
#
# In the next section, answer a few questions regarding your dataset using the visualizations you've generated.

# %% [markdown]
# ### Q1
#
# What was the hypothesis?

# %% [markdown]
# Answer: Up to this point, the data is alignment with the anticipated results. The exemplified variable relationships are further represented in their specified visualizations.

# %% [markdown]
# ### Q2
#
# What were you most surprized to detect concerning the visualizations? Indicate at least one point.

# %% [markdown]
# Answer: The existence of the normal distribution being detected within the histoplot for the Metascore. This was very interesting knowing that there was a longitudinal study provided. This seemed to display an understanding of what a low, medium and high score would constitute within the range as well.
